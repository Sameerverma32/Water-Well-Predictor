# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv('groundwater_ml_dataset.csv')
df.head(10)
# Out:
#     state                           district  annual_recharge  \
# 0       1                               Safe           4951.0
# 1       2                      Semi Critical            711.0
# 2       3                           Critical            206.0
# 3       4                     Over-Exploited            751.0
# 4       5                             Saline            127.0
# 5  S. No.  Ground Water Resources Assessment           2004.0
# 6       2                               Safe           4078.0
# 7       3                      Semi-critical            550.0
# 8       4                           Critical            226.0
# 9       5                     Over-Exploited            839.0
#
#    extractable_resource  annual_extraction  stage_of_development  \
# 0                 73.39              16.51                 66.57
# 1                 10.54               2.82                 11.40
# 2                  3.05               0.88                  3.55
# ...

# %%
df.isnull().sum()
# Out:
# state                   0
# district                0
# annual_recharge         0
# extractable_resource    0
# annual_extraction       0
# stage_of_development    0
# category                0
# extraction_ratio        0
# utilization_rate        0
# stress_level            0
# risk_score              0
# year                    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['state', 'district', 'annual_recharge', 'extractable_resource',
#        'annual_extraction', 'stage_of_development', 'category',
#        'extraction_ratio', 'utilization_rate', 'stress_level', 'risk_score',
#        'year'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1932 entries, 0 to 1931
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   state                 1932 non-null   object
#  1   district              1932 non-null   object
#  2   annual_recharge       1932 non-null   float64
#  3   extractable_resource  1932 non-null   float64
#  4   annual_extraction     1932 non-null   float64
#  5   stage_of_development  1932 non-null   float64
#  6   category              1932 non-null   object
#  7   extraction_ratio      1932 non-null   float64
#  8   utilization_rate      1932 non-null   float64
#  9   stress_level          1932 non-null   float64
#  10  risk_score            1932 non-null   float64
#  11  year                  1932 non-null   int64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 181.3+ KB

# %%
df.tail()
# Out:
#      state       district  annual_recharge  extractable_resource  \
# 1927    24      Telangana            620.0                   9.0
# 1928    26  Uttar Pradesh            836.0                  22.0
# 1929    28    West Bengal            345.0                   4.0
# 1930    30     Chandigarh              1.0                   1.0
# 1931    36         Ladakh             18.0                   5.0
#
#       annual_extraction  stage_of_development        category  \
# 1927               76.0                 527.0  Over Exploited
# 1928               12.0                 802.0  Over Exploited
# 1929                4.0                 337.0  Over Exploited
# 1930                0.0                   0.0            Safe
# 1931                0.0                  13.0            Safe
#
#       extraction_ratio  utilization_rate  stress_level  risk_score  year
# 1927          0.122581          8.444444          5.27    4.480810  2024
# ...

# %%
df.describe()
# Out:
#        annual_recharge  extractable_resource  annual_extraction  \
# count     1.932000e+03           1932.000000       1.932000e+03
# mean      2.498134e+04           9044.642834       3.981354e+03
# std       4.242728e+04          14319.993642       4.925726e+04
# min       1.000000e-02              0.001000       0.000000e+00
# 25%       1.087050e+03            416.217500       5.334500e+01
# 50%       1.634041e+04           2566.885000       3.027250e+02
# 75%       3.656483e+04          12023.240000       2.606145e+03
# max       1.412285e+06         102516.480000       2.147413e+06
#
#        stage_of_development  extraction_ratio  utilization_rate  stress_level  \
# count          1.932000e+03       1932.000000       1932.000000   1932.000000
# mean           1.375984e+04          2.019403        197.685596    137.598428
# std            1.663539e+05         34.489025       5859.608905   1663.538529
# ...

# %%
df.iloc[10:31]
# Out:
#    state           district  annual_recharge  extractable_resource  \
# 10     6             Saline            30.00                  0.50
# 11     2              ASSAM             0.50                 26.00
# 12     3          MEGHALAYA             0.10                  7.40
# 13     4           NAGALAND             0.30                  2.10
# 14     8             SIKKIM             0.70                 99.00
# 15     9        WEST BENGAL             0.10                  1.70
# 16    13        UTTARAKHAND            30.60                  6.60
# 17    17             PUNJAB            15.10                  0.10
# 18    18    HIMACHALPRADESH            86.80                 30.00
# 19    20         LADAKH(UT)             9.90                 12.00
# 20    29  A & N ISLAND (UT)            27.40                 24.00
# 21    32          TAMILNADU             5.10                 16.00
# 22    33    PUDUCHERRY (UT)             6.20                 42.00
# ...

# %%
df.iloc[70:91]
# Out:
#    state                     district  annual_recharge  extractable_resource  \
# 70    13                      Kurnool         38342.94              17638.70
# 71    14                          Ntr         20780.78              28090.65
# 72    15                      Nandyal         22651.71              40388.65
# 73    16                      Palnadu         25660.06              55379.59
# 74    17         Parvathipuram Manyam         29763.31              35032.83
# 75    18                     Prakasam         63974.15              19744.85
# 76    19  Sri Potti Sriramulu Nellore         68345.39              36991.28
# 77    20               Sri Sathya Sai         43077.78              31974.68
# 78    21                   Srikakulam         34587.38              66648.48
# 79    22                     Tirupati         81366.63              27763.10
# 80    23                Visakhapatnam          7995.13               3262.26
# ...

# %%
fig = px.pie(df, names="stage_of_development", title="Stage Distribution")
fig.show()

# %%
fig = px.scatter(df, x="risk_score", y="extraction_ratio",
                color="category",
                title="Risk vs Extraction Ratio")
fig.show()

# %%
fig = px.sunburst(df, path=["state", "category", "district"], values="annual_extraction", title="Sunburst Chart")
fig.show()
